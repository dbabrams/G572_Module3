# %% [markdown]
# # Reading data from online web services
#
# The following code walks through the process of reading web services from the USGS.

# %%
import matplotlib.pyplot as plt
import pandas as pd
# import data from online
import urllib, json
from datetime import datetime
# %matplotlib inline

# %% [markdown]
# ## A quick detour: Dictionaries
#
# A dictionary is a collection which is unordered, changeable and indexed. In Python dictionaries are written with curly brackets, and they have keys and values. Some interactive tutorials: https://www.w3schools.com/python/python_dictionaries.asp
#
# More in-depth tutorials and discussion about Python data types: https://www.datacamp.com/community/tutorials/python-dictionary-tutorial

# %%
# Example Dictionary: Big Ten Football Champions
B10Champs = {'2014': ['Ohio State','14-1'], '2015': ['Michigan State','12-2'], '2016': ['Penn State','11-3'], '2017': ['Ohio State','12-2'], '2018': ['Ohio State','13-1']}

# %%
print(B10Champs['2016'])
# Out:
# ['Penn State', '11-3']

# %%
for key, value in B10Champs.items():
    print('The', key, 'Big 10 Football champion was',value[0],'with a record of',value[1])
# Out:
# The 2014 Big 10 Football champion was Ohio State with a record of 14-1
# The 2015 Big 10 Football champion was Michigan State with a record of 12-2
# The 2016 Big 10 Football champion was Penn State with a record of 11-3
# The 2017 Big 10 Football champion was Ohio State with a record of 12-2
# The 2018 Big 10 Football champion was Ohio State with a record of 13-1

# %% [markdown]
# ## Obtaining real-time data from the USGS
#
# Let's extract real-time data from a USGS monitoring well in Lee County, a heavily irrigated area of Illinois: https://waterdata.usgs.gov/il/nwis/uv/?site_no=413743089310102&PARAmeter_cd=72019,72020
#
# To start, visit the following page and create a link to gather the appropriate data: https://waterservices.usgs.gov/rest/IV-Test-Tool.html
#
# We want the last 500 days of depth-to-water data (72019) for the site 413743089310102.

# %% [markdown]
# ## Let's first create the URL we are going to extract data from

# %%
siteNum = "413743089310102"
period_of_days = "500"
USGSparameter = "72019"

# URL with streamflow/groundwater data from the USGS
url = 'https://waterservices.usgs.gov/nwis/iv/?format=json&sites=' + siteNum + '&period=P'+ period_of_days +'D&parameterCd=' + USGSparameter + '&siteStatus=all'

# %% [markdown]
# ## Let's open the URL and read the data in
#
# First, we have to request to open the url, using urllib.request.urlopen(). Next, we have to load the json-formatted data, which will be read in as a dictionary

# %%
#open the URL
response = urllib.request.urlopen(url)
# read the data in as a dictionary
gw_data = json.loads(response.read())

# %%
gw_data.keys()
# Out:
# dict_keys(['name', 'declaredType', 'scope', 'value', 'nil', 'globalScope', 'typeSubstituted'])

# %%
gw_data['value'].keys()
# Out:
# dict_keys(['queryInfo', 'timeSeries'])

# %%
gw_data['value']['queryInfo']
# Out:
# {'queryURL': 'http://nwis.waterservices.usgs.gov/nwis/iv/format=json&sites=413743089310102&period=P500D&parameterCd=72019&siteStatus=all',
#  'criteria': {'locationParam': '[ALL:413743089310102]',
#   'variableParam': '[72019]',
#   'parameter': []},
#  'note': [{'value': '[ALL:413743089310102]', 'title': 'filter:sites'},
#   {'value': '[mode=PERIOD, period=P500D, modifiedSince=null]',
#    'title': 'filter:timeRange'},
#   {'value': 'methodIds=[ALL]', 'title': 'filter:methodId'},
#   {'value': '2021-02-28T23:36:52.431Z', 'title': 'requestDT'},
#   {'value': 'd5c91ee0-7a1d-11eb-b376-4cd98f86fad9', 'title': 'requestId'},
#   {'value': 'Provisional data are subject to revision. Go to http://waterdata.usgs.gov/nwis/help/?provisional for more information.',
#    'title': 'disclaimer'},
#   {'value': 'nadww02', 'title': 'server'}]}

# %%
# note that gw_data['value']['timeSeries'] returns a list with one entry, which is a dictionary. Return the keys for that
gw_data['value']['timeSeries'][0].keys()
# Out:
# dict_keys(['sourceInfo', 'variable', 'values', 'name'])

# %%
# now we obtain source information, you will need this for your homework
gw_data['value']['timeSeries'][0]['sourceInfo']
# Out:
# {'siteName': '19N8E-13.1a2 (LEE-92E)',
#  'siteCode': [{'value': '413743089310102',
#    'network': 'NWIS',
#    'agencyCode': 'USGS'}],
#  'timeZoneInfo': {'defaultTimeZone': {'zoneOffset': '-06:00',
#    'zoneAbbreviation': 'CST'},
#   'daylightSavingsTimeZone': {'zoneOffset': '-05:00',
#    'zoneAbbreviation': 'CDT'},
#   'siteUsesDaylightSavingsTime': False},
#  'geoLocation': {'geogLocation': {'srs': 'EPSG:4326',
#    'latitude': 41.62877778,
#    'longitude': -89.5169444},
#   'localSiteXY': []},
#  'note': [],
#  'siteType': [],
#  'siteProperty': [{'value': 'GW', 'name': 'siteTypeCd'},
#   {'value': '07090007', 'name': 'hucCd'},
#   {'value': '17', 'name': 'stateCd'},
#   {'value': '17103', 'name': 'countyCd'}]}

# %%
gw_data['value']['timeSeries'][0]['values']
# Out:
# [{'value': [{'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-17T17:45:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-17T18:00:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-17T18:15:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-17T18:30:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-17T18:45:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-17T19:00:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-17T19:15:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-17T19:30:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-17T19:45:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-17T20:00:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-17T20:15:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-17T20:30:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-17T20:45:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-17T21:00:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-17T21:15:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-17T21:30:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-17T21:45:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-17T22:00:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-17T22:15:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-17T22:30:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-17T22:45:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-17T23:00:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-17T23:15:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-17T23:30:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-17T23:45:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T00:00:00.000-06:00'},
#    {'value': '22.37',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T00:15:00.000-06:00'},
#    {'value': '22.37',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T00:30:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T00:45:00.000-06:00'},
#    {'value': '22.37',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T01:00:00.000-06:00'},
#    {'value': '22.37',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T01:15:00.000-06:00'},
#    {'value': '22.37',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T01:30:00.000-06:00'},
#    {'value': '22.37',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T01:45:00.000-06:00'},
#    {'value': '22.37',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T02:00:00.000-06:00'},
#    {'value': '22.37',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T02:15:00.000-06:00'},
#    {'value': '22.37',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T02:30:00.000-06:00'},
#    {'value': '22.37',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T02:45:00.000-06:00'},
#    {'value': '22.37',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T03:00:00.000-06:00'},
#    {'value': '22.37',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T03:15:00.000-06:00'},
#    {'value': '22.37',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T03:30:00.000-06:00'},
#    {'value': '22.37',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T03:45:00.000-06:00'},
#    {'value': '22.37',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T04:00:00.000-06:00'},
#    {'value': '22.37',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T04:15:00.000-06:00'},
#    {'value': '22.37',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T04:30:00.000-06:00'},
#    {'value': '22.37',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T04:45:00.000-06:00'},
#    {'value': '22.37',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T05:00:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T05:15:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T05:30:00.000-06:00'},
#    {'value': '22.37',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T05:45:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T06:00:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T06:15:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T06:30:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T06:45:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T07:00:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T07:15:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T07:30:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T07:45:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T08:00:00.000-06:00'},
#    {'value': '22.37',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T08:15:00.000-06:00'},
#    {'value': '22.37',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T08:30:00.000-06:00'},
#    {'value': '22.37',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T08:45:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T09:00:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T09:15:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T09:30:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T09:45:00.000-06:00'},
#    {'value': '22.37',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T10:00:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T10:15:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T10:30:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T10:45:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T11:00:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T11:15:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T11:30:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T11:45:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T12:00:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T12:15:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T12:30:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T12:45:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T13:00:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T13:15:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T13:30:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T13:45:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T14:00:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T14:15:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T14:30:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T14:45:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T15:00:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T15:15:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T15:30:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T15:45:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T16:00:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T16:15:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T16:30:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T16:45:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T17:00:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T17:15:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T17:30:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T17:45:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T18:00:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T18:15:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T18:30:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T18:45:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T19:00:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T19:15:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T19:30:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T19:45:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T20:00:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T20:15:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T20:30:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T20:45:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T21:00:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T21:15:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T21:30:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T21:45:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T22:00:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T22:15:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T22:30:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T22:45:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T23:00:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T23:15:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T23:30:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-18T23:45:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-19T00:00:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-19T00:15:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-19T00:30:00.000-06:00'},
#    {'value': '22.34',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-19T00:45:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-19T01:00:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-19T01:15:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-19T01:30:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-19T01:45:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-19T02:00:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-19T02:15:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-19T02:30:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-19
00:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-28T00:15:00.000-06:00'},
#    {'value': '22.37',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-28T00:30:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-28T00:45:00.000-06:00'},
#    {'value': '22.37',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-28T01:00:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-28T01:15:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-28T01:30:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-28T01:45:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-28T02:00:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-28T02:15:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-28T02:30:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-28T02:45:00.000-06:00'},
#    {'value': '22.36',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-28T03:00:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-28T03:15:00.000-06:00'},
#    {'value': '22.35',
#     'qualifiers': ['A'],
#     'dateTime': '2019-10-28T03:30:00.000-06:00'},
#    ...],
#   'qualifier': [{'qualifierCode': 'A',
#     'qualifierDescription': 'Approved for publication -- Processing and review completed.',
#     'qualifierID': 0,
#     'network': 'NWIS',
#     'vocabulary': 'uv_rmk_cd'},
#    {'qualifierCode': 'P',
#     'qualifierDescription': 'Provisional data subject to revision.',
#     'qualifierID': 1,
#     'network': 'NWIS',
#     'vocabulary': 'uv_rmk_cd'}],
#   'qualityControlLevel': [],
#   'method': [{'methodDescription': '', 'methodID': 51189}],
#   'source': [],
#   'offset': [],
#   'sample': [],
#   'censorCode': []}]

# %% [markdown]
# ## Now let's extract the data from the dictionary that we actually need

# %%
# extract the list of dictionaries containing time series and value information
gw_data2 = gw_data['value']['timeSeries'][0]['values'][0]['value']
# extract the site name
sitename = gw_data['value']['timeSeries'][0]['sourceInfo']['siteName']

# %%
dtw = pd.DataFrame.from_dict(gw_data2)
dtw.index = pd.to_datetime(dtw['dateTime'])
dtw = dtw.drop(columns=['qualifiers','dateTime'])
print(dtw)
# Out:
#                            value
# dateTime
# 2019-10-17 17:45:00-06:00  22.34
# 2019-10-17 18:00:00-06:00  22.34
# 2019-10-17 18:15:00-06:00  22.35
# 2019-10-17 18:30:00-06:00  22.35
# 2019-10-17 18:45:00-06:00  22.35
# ...                          ...
# 2021-02-28 15:45:00-06:00  23.88
# 2021-02-28 16:00:00-06:00  23.88
# 2021-02-28 16:15:00-06:00  23.88
# 2021-02-28 16:30:00-06:00  23.88
# 2021-02-28 16:45:00-06:00  23.88
#
# [47719 rows x 1 columns]

# %% [markdown]
# ## Next create a list for the time series and values

# %%
# Initialize arrays to store time and gage data
gw_gage = []
gw_time = [] # Datatype needs to be datetime here
# Add data from list of dictionaries into an array for time and gage
# note that gage requires conversion to a date time
for x in gw_data2:
    # add gage data, must convert from string to float
    gw_gage.append(float(x['value']))
    # extract date
    date = x['dateTime']
    datestr = date[:-10] # Don't include the last ten digits
    dat_time = datetime.strptime(datestr, '%Y-%m-%dT%H:%M:%S') # Convert string to datetime
    # append date time
    gw_time.append(dat_time)

# %% [markdown]
# ## Finally let's plot the data

# %%
# control size of plot
plt.rcParams['figure.figsize'] = 10,10
# plot time vs gage (depth to water)
plt.plot(gw_time,gw_gage)
# add title with sitename and date
plt.title(sitename + ' \n ' + 'Most recent measurement: ' + str(dat_time), fontweight = 'bold')
plt.xticks(rotation=30)
plt.xlabel('date')
plt.ylabel('USGS Parameter '+USGSparameter)
if USGSparameter == '72019':
    plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()
